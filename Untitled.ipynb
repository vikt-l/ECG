# %%
import pandas as pd

# %%
data = pd.read_csv('train/train_meta.csv')
data
# Out:
#       ecg_id  patient_id    age  sex  height  weight  nurse  site      device  \
# 0          9     18792.0   55.0    0     NaN    70.0    2.0   0.0   CS-12   E
# 1         34     13619.0   56.0    0     NaN     NaN    2.0   0.0   CS-12   E
# 2         43     11315.0   25.0    1     NaN    63.0    2.0   0.0   CS-12   E
# 3         52     18153.0   35.0    0     NaN    82.0    2.0   0.0   CS-12   E
# 4         57     16063.0   26.0    0     NaN    93.0    2.0   0.0   CS-12   E
# ...      ...         ...    ...  ...     ...     ...    ...   ...         ...
# 2096   21784     12488.0   66.0    1     NaN     NaN    0.0   0.0  CS100    3
# 2097   21795     10162.0   68.0    0     NaN     NaN    1.0   2.0  AT-60    3
# 2098   21825     11197.0   59.0    0     NaN     NaN    1.0   2.0  AT-60    3
# 2099   21831     11905.0   55.0    1     NaN     NaN    1.0   2.0  AT-60    3
# 2100   21834     20703.0  300.0    0     NaN     NaN    1.0   2.0  AT-60    3
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2101 entries, 0 to 2100
# Data columns (total 30 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ecg_id                        2101 non-null   int64
#  1   patient_id                    2101 non-null   float64
#  2   age                           2101 non-null   float64
#  3   sex                           2101 non-null   int64
#  4   height                        689 non-null    float64
#  5   weight                        905 non-null    float64
#  6   nurse                         1947 non-null   float64
#  7   site                          2100 non-null   float64
#  8   device                        2101 non-null   object
#  9   recording_date                2101 non-null   object
#  10  report                        2101 non-null   object
#  11  scp_codes                     2101 non-null   object
# ...
